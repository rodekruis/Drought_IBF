# %%
# %matplotlib inline 
import matplotlib.pylab as plt 
plt.rcParams.update({'figure.max_open_warning': 0})
import numpy as np 
import pandas as pd 
import seaborn as sns 
from sklearn.cluster.bicluster import SpectralBiclustering
import importlib
import drought_ibf_utility as ibf
importlib.reload(ibf)
# Out:
# <module 'drought_ibf_utility' from 'D:\\Behrouz\\Big_data\\Red_Cross\\Drought_IBF\\Model Event Data\\drought_ibf_utility.py'>

# %%
filename = './datasets/Uganda_seasonal_normalized.csv'
data = pd.read_csv(filename)
data.dropna(inplace=True)
data.head()
# Out:
#    year  District Season       EVI      NDVI  SPEI_3month  \
# 0  2000      ABIM  11_12  0.635496  0.232554     0.946693
# 1  2000      ABIM    6_7 -1.590836 -1.720571     0.075238
# 2  2000  ADJUMANI  11_12 -1.085335 -1.260320    -0.606487
# 3  2000  ADJUMANI    6_7 -2.697474 -3.056846    -0.816605
# 4  2000     AGAGO  11_12  1.149972 -0.070580     0.824262
#
#    SoilMoisture00_10cm  SoilMoisture100_200cm  SoilMoisture10_40cm  \
# 0             0.876312               0.199678             0.736812
# 1            -1.302612              -1.113239            -1.262019
# 2            -0.724946              -0.722124            -0.683251
# 3            -0.872943               0.243240            -0.161562
# 4             0.874588               0.624983             0.793872
#
#    SoilMoisture40_100cm  ...  air_temperature  evapotranspiration  \
# 0              0.605763  ...        -0.435935            1.208654
# 1             -0.937505  ...         1.570308           -0.740945
# 2             -0.829818  ...        -0.221168           -1.138716
# 3              0.000243  ...         1.546512           -0.115219
# 4              0.710458  ...        -0.380892            1.126550
#
#    precipitation_per_hour_v1  precipitation_per_hour_v2  rainfall  \
# 0                   1.601028                  -0.469460  1.336204
# 1                  -0.358292                  -1.030145 -0.388903
# 2                   0.041021                  -2.093348 -1.024165
# 3                  -1.671680                  -1.859843 -0.681410
# 4                   1.366786                   0.265181  0.963633
#
#    surface_temperature_daytime  surface_temperature_nighttime  water_balance  \
# 0                    -0.151764                      -1.343323       0.841488
# 1                     1.260564                       0.032762      -0.114317
# 2                     1.721439                      -1.782573      -0.675508
# 3                     2.350867                      -0.480881      -0.793150
# 4                    -0.414698                      -2.063056       0.573377
#
#    wind_speed  drought_reported
# 0   -0.412148             False
# 1    0.306375             False
# 2   -0.412293             False
# 3    0.608132             False
# 4   -0.467823             False
#
# [5 rows x 24 columns]

# %%
id_cols = ['year','District','Season']

label_name = 'drought_reported'

All_features = list(data.drop(labels=id_cols+[label_name], 
                                  axis=1).columns)

# %%
reduced_data = ibf.reduce_data(data,label_name)

# %%
features = reduced_data[All_features].copy()
feature_corr = features.corr().abs()

bicluster_model = SpectralBiclustering(n_clusters=3, method='log',
                             random_state=0)
bicluster_model.fit(feature_corr)
feature_corr_sorted = feature_corr.values[np.argsort(bicluster_model.row_labels_),:]
feature_corr_sorted = feature_corr_sorted[:, np.argsort(bicluster_model.column_labels_)]
rows = feature_corr.columns[np.argsort(bicluster_model.row_labels_)]
cols = feature_corr.columns[np.argsort(bicluster_model.column_labels_)]
feature_corr_sorted = pd.DataFrame(feature_corr_sorted,index=rows,columns=cols)
sns.heatmap(feature_corr_sorted,cmap='coolwarm')
feature_corr_sorted
# Out:
#                                     EVI      NDVI  \
# EVI                            1.000000  0.876824
# NDVI                           0.876824  1.000000
# surface_temperature_nighttime  0.179109  0.196783
# surface_temperature_daytime    0.738907  0.730287
# air_temperature                0.560195  0.469747
# evapotranspiration             0.391268  0.394463
# SoilTemperature40_100cm        0.572731  0.502899
# SoilTemperature100_200cm       0.541593  0.486367
# SoilTemperature10_40cm         0.580934  0.502019
# SoilMoisture40_100cm           0.378691  0.319544
# SoilMoisture10_40cm            0.451269  0.395720
# SoilMoisture100_200cm          0.164817  0.137697
# SoilMoisture00_10cm            0.502302  0.445350
# SoilTemperature00_10cm         0.570941  0.482754
# water_balance                  0.321906  0.245421
# precipitation_per_hour_v1      0.278964  0.230167
# precipitation_per_hour_v2      0.275295  0.227885
# rainfall                       0.411251  0.352660
# SPEI_3month                    0.299335  0.236666
# wind_speed                     0.203378  0.186935
#
#                                surface_temperature_nighttime  \
# EVI                                                 0.179109
# NDVI                                                0.196783
# surface_temperature_nighttime                       1.000000
# surface_temperature_daytime                         0.351859
# air_temperature                                     0.385112
# evapotranspiration                                  0.118886
# SoilTemperature40_100cm                             0.348729
# SoilTemperature100_200cm                            0.362551
# SoilTemperature10_40cm                              0.342838
# SoilMoisture40_100cm                                0.000372
# SoilMoisture10_40cm                                 0.023110
# SoilMoisture100_200cm                               0.034585
# SoilMoisture00_10cm                                 0.075939
# SoilTemperature00_10cm                              0.343478
# water_balance                                       0.145798
# precipitation_per_hour_v1                           0.374719
# precipitation_per_hour_v2                           0.063367
# rainfall                                            0.163236
# SPEI_3month                                         0.103589
# wind_speed                                          0.276973
#
#                                surface_temperature_daytime  air_temperature  \
# EVI                                               0.738907         0.560195
# NDVI                                              0.730287         0.469747
# surface_temperature_nighttime                     0.351859         0.385112
# surface_temperature_daytime                       1.000000         0.653017
# air_temperature                                   0.653017         1.000000
# evapotranspiration                                0.422645         0.381459
# SoilTemperature40_100cm                           0.642663         0.871291
# SoilTemperature100_200cm                          0.615225         0.816779
# SoilTemperature10_40cm                            0.652613         0.895548
# SoilMoisture40_100cm                              0.404549         0.540526
# SoilMoisture10_40cm                               0.464051         0.605036
# SoilMoisture100_200cm                             0.207844         0.398302
# SoilMoisture00_10cm                               0.514984         0.647697
# SoilTemperature00_10cm                            0.651245         0.913256
# water_balance                                     0.381095         0.542185
# precipitation_per_hour_v1                         0.469072         0.402324
# precipitation_per_hour_v2                         0.362800         0.443073
# rainfall                                          0.471565         0.571771
# SPEI_3month                                       0.331566         0.476156
# wind_speed                                        0.351421         0.365570
#
#                                evapotranspiration  SoilTemperature40_100cm  \
# EVI                                      0.391268                 0.572731
# NDVI                                     0.394463                 0.502899
# surface_temperature_nighttime            0.118886                 0.348729
# surface_temperature_daytime              0.422645                 0.642663
# air_temperature                          0.381459                 0.871291
# evapotranspiration                       1.000000                 0.665421
# SoilTemperature40_100cm                  0.665421                 1.000000
# SoilTemperature100_200cm                 0.651454                 0.984815
# SoilTemperature10_40cm                   0.664346                 0.993774
# SoilMoisture40_100cm                     0.782740                 0.734832
# SoilMoisture10_40cm                      0.833038                 0.789618
# SoilMoisture100_200cm                    0.547028                 0.557000
# SoilMoisture00_10cm                      0.833183                 0.805482
# SoilTemperature00_10cm                   0.645895                 0.963758
# water_balance                            0.406268                 0.462056
# precipitation_per_hour_v1                0.220132                 0.294942
# precipitation_per_hour_v2                0.346371                 0.365533
# rainfall                                 0.769358                 0.655783
# SPEI_3month                              0.415340                 0.430670
# wind_speed                               0.334728                 0.376815
#
#                                SoilTemperature100_200cm  \
# EVI                                            0.541593
# NDVI                                           0.486367
# surface_temperature_nighttime                  0.362551
# surface_temperature_daytime                    0.615225
# air_temperature                                0.816779
# evapotranspiration                             0.651454
# SoilTemperature40_100cm                        0.984815
# SoilTemperature100_200cm                       1.000000
# SoilTemperature10_40cm                         0.960593
# SoilMoisture40_100cm                           0.708916
# SoilMoisture10_40cm                            0.746926
# SoilMoisture100_200cm                          0.565621
# SoilMoisture00_10cm                            0.751347
# SoilTemperature00_10cm                         0.909714
# water_balance                                  0.373763
# precipitation_per_hour_v1                      0.240012
# precipitation_per_hour_v2                      0.308731
# rainfall                                       0.588444
# SPEI_3month                                    0.351796
# wind_speed                                     0.345579
#
#                                SoilTemperature10_40cm  SoilMoisture40_100cm  \
# EVI                                          0.580934              0.378691
# NDVI                                         0.502019              0.319544
# surface_temperature_nighttime                0.342838              0.000372
# surface_temperature_daytime                  0.652613              0.404549
# air_temperature                              0.895548              0.540526
# evapotranspiration                           0.664346              0.782740
# SoilTemperature40_100cm                      0.993774              0.734832
# SoilTemperature100_200cm                     0.960593              0.708916
# SoilTemperature10_40cm                       1.000000              0.739960
# SoilMoisture40_100cm                         0.739960              1.000000
# SoilMoisture10_40cm                          0.803337              0.952822
# SoilMoisture100_200cm                        0.546942              0.798139
# SoilMoisture00_10cm                          0.827725              0.893637
# SoilTemperature00_10cm                       0.986371              0.736323
# water_balance                                0.521315              0.471116
# precipitation_per_hour_v1                    0.333569              0.168852
# precipitation_per_hour_v2                    0.405107              0.459290
# rainfall                                     0.695680              0.722200
# SPEI_3month                                  0.483049              0.455195
# wind_speed                                   0.401743              0.389140
#
#                                SoilMoisture10_40cm  SoilMoisture100_200cm  \
# EVI                                       0.451269               0.164817
# NDVI                                      0.395720               0.137697
# surface_temperature_nighttime             0.023110               0.034585
# surface_temperature_daytime               0.464051               0.207844
# air_temperature                           0.605036               0.398302
# evapotranspiration                        0.833038               0.547028
# SoilTemperature40_100cm                   0.789618               0.557000
# SoilTemperature100_200cm                  0.746926               0.565621
# SoilTemperature10_40cm                    0.803337               0.546942
# SoilMoisture40_100cm                      0.952822               0.798139
# SoilMoisture10_40cm                       1.000000               0.701825
# SoilMoisture100_200cm                     0.701825               1.000000
# SoilMoisture00_10cm                       0.965357               0.648498
# SoilTemperature00_10cm                    0.804502               0.528358
# water_balance                             0.563916               0.273109
# precipitation_per_hour_v1                 0.223169               0.018940
# precipitation_per_hour_v2                 0.469283               0.381063
# rainfall                                  0.810226               0.472772
# SPEI_3month                               0.561615               0.255236
# wind_speed                                0.398634               0.311759
#
#                                SoilMoisture00_10cm  SoilTemperature00_10cm  \
# EVI                                       0.502302                0.570941
# NDVI                                      0.445350                0.482754
# surface_temperature_nighttime             0.075939                0.343478
# surface_temperature_daytime               0.514984                0.651245
# air_temperature                           0.647697                0.913256
# evapotranspiration                        0.833183                0.645895
# SoilTemperature40_100cm                   0.805482                0.963758
# SoilTemperature100_200cm                  0.751347                0.909714
# SoilTemperature10_40cm                    0.827725                0.986371
# SoilMoisture40_100cm                      0.893637                0.736323
# SoilMoisture10_40cm                       0.965357                0.804502
# SoilMoisture100_200cm                     0.648498                0.528358
# SoilMoisture00_10cm                       1.000000                0.839553
# SoilTemperature00_10cm                    0.839553                1.000000
# water_balance                             0.632688                0.605447
# precipitation_per_hour_v1                 0.297888                0.387325
# precipitation_per_hour_v2                 0.485817                0.461233
# rainfall                                  0.854182                0.744352
# SPEI_3month                               0.617501                0.559266
# wind_speed                                0.450761                0.439123
#
#                                water_balance  precipitation_per_hour_v1  \
# EVI                                 0.321906                   0.278964
# NDVI                                0.245421                   0.230167
# surface_temperature_nighttime       0.145798                   0.374719
# surface_temperature_daytime         0.381095                   0.469072
# air_temperature                     0.542185                   0.402324
# evapotranspiration                  0.406268                   0.220132
# SoilTemperature40_100cm             0.462056                   0.294942
# SoilTemperature100_200cm            0.373763                   0.240012
# SoilTemperature10_40cm              0.521315                   0.333569
# SoilMoisture40_100cm                0.471116                   0.168852
# SoilMoisture10_40cm                 0.563916                   0.223169
# SoilMoisture100_200cm               0.273109                   0.018940
# SoilMoisture00_10cm                 0.632688                   0.297888
# SoilTemperature00_10cm              0.605447                   0.387325
# water_balance                       1.000000                   0.472529
# precipitation_per_hour_v1           0.472529                   1.000000
# precipitation_per_hour_v2           0.583029                   0.440766
# rainfall                            0.885519                   0.433925
# SPEI_3month                         0.961046                   0.404064
# wind_speed                          0.412612                   0.249275
#
#                                precipitation_per_hour_v2  rainfall  \
# EVI                                             0.275295  0.411251
# NDVI                                            0.227885  0.352660
# surface_temperature_nighttime                   0.063367  0.163236
# surface_temperature_daytime                     0.362800  0.471565
# air_temperature                                 0.443073  0.571771
# evapotranspiration                              0.346371  0.769358
# SoilTemperature40_100cm                         0.365533  0.655783
# SoilTemperature100_200cm                        0.308731  0.588444
# SoilTemperature10_40cm                          0.405107  0.695680
# SoilMoisture40_100cm                            0.459290  0.722200
# SoilMoisture10_40cm                             0.469283  0.810226
# SoilMoisture100_200cm                           0.381063  0.472772
# SoilMoisture00_10cm                             0.485817  0.854182
# SoilTemperature00_10cm                          0.461233  0.744352
# water_balance                                   0.583029  0.885519
# precipitation_per_hour_v1                       0.440766  0.433925
# precipitation_per_hour_v2                       1.000000  0.578165
# rainfall                                        0.578165  1.000000
# SPEI_3month                                     0.536085  0.862222
# wind_speed                                      0.342496  0.443933
#
#                                SPEI_3month  wind_speed
# EVI                               0.299335    0.203378
# NDVI                              0.236666    0.186935
# surface_temperature_nighttime     0.103589    0.276973
# surface_temperature_daytime       0.331566    0.351421
# air_temperature                   0.476156    0.365570
# evapotranspiration                0.415340    0.334728
# SoilTemperature40_100cm           0.430670    0.376815
# SoilTemperature100_200cm          0.351796    0.345579
# SoilTemperature10_40cm            0.483049    0.401743
# SoilMoisture40_100cm              0.455195    0.389140
# SoilMoisture10_40cm               0.561615    0.398634
# SoilMoisture100_200cm             0.255236    0.311759
# SoilMoisture00_10cm               0.617501    0.450761
# SoilTemperature00_10cm            0.559266    0.439123
# water_balance                     0.961046    0.412612
# precipitation_per_hour_v1         0.404064    0.249275
# precipitation_per_hour_v2         0.536085    0.342496
# rainfall                          0.862222    0.443933
# SPEI_3month                       1.000000    0.370009
# wind_speed                        0.370009    1.000000

# %%
median_vals = reduced_data[All_features+[label_name]].groupby(label_name).median().T.reset_index()
median_vals.rename(columns={True:'yes_drought', False:'no_drought', 'Is_drought':'index'}, inplace= True)
median_vals['diff'] = (median_vals['yes_drought']-median_vals['no_drought']).abs()
median_vals.sort_values('diff',ascending=False,inplace=True)
median_vals.reset_index(inplace=True,drop=True)
median_vals
# Out:
# drought_reported                          index  no_drought  yes_drought  \
# 0                           SoilMoisture00_10cm    0.280299    -0.570226
# 1                     precipitation_per_hour_v2    0.063213    -0.698218
# 2                           SoilMoisture10_40cm    0.216020    -0.530722
# 3                          SoilMoisture40_100cm    0.203412    -0.531513
# 4                            evapotranspiration    0.044880    -0.602795
# 5                                      rainfall    0.158049    -0.486975
# 6                      SoilTemperature100_200cm   -0.268359     0.320006
# 7                       SoilTemperature40_100cm   -0.224721     0.361192
# 8                        SoilTemperature10_40cm   -0.211171     0.302455
# 9                        SoilTemperature00_10cm   -0.144578     0.340174
# 10                                water_balance    0.101895    -0.349032
# 11                                          EVI    0.214773    -0.196214
# 12                                  SPEI_3month    0.211545    -0.192696
# 13                                   wind_speed   -0.024963     0.329311
# 14                    precipitation_per_hour_v1   -0.240641    -0.549282
# 15                                         NDVI    0.141345    -0.127157
# 16                        SoilMoisture100_200cm   -0.036950    -0.292951
# 17                  surface_temperature_daytime   -0.092329     0.155518
# 18                              air_temperature   -0.153588     0.028358
# 19                surface_temperature_nighttime    0.090008     0.235946
#
# drought_reported      diff
# 0                 0.850525
# 1                 0.761430
# 2                 0.746742
# 3                 0.734925
# 4                 0.647675
# 5                 0.645024
# 6                 0.588365
# 7                 0.585913
# 8                 0.513625
# 9                 0.484752
# 10                0.450926
# 11                0.410986
# 12                0.404242
# 13                0.354275
# 14                0.308641
# 15                0.268502
# 16                0.256001
# 17                0.247847
# 18                0.181946
# 19                0.145938

# %%
targets = feature_corr_sorted.columns

for target in targets:
    ibf.plot_dist(reduced_data,target,label_name)

# %%
gruop_1 = feature_corr.columns[bicluster_model.row_labels_==1]

print(list(gruop_1))

sns.pairplot(reduced_data, vars=gruop_1, hue=label_name)
# Out:
# ['SoilMoisture00_10cm', 'SoilMoisture100_200cm', 'SoilMoisture10_40cm', 'SoilMoisture40_100cm', 'SoilTemperature00_10cm', 'SoilTemperature100_200cm', 'SoilTemperature10_40cm', 'SoilTemperature40_100cm', 'evapotranspiration']

# %%
gruop_0 = feature_corr.columns[bicluster_model.row_labels_==0]

print(gruop_0)

sns.pairplot(reduced_data, vars=gruop_0, hue=label_name)
# Out:
# Index(['EVI', 'NDVI', 'air_temperature', 'surface_temperature_daytime',
#        'surface_temperature_nighttime'],
#       dtype='object')

# %%
gruop_2 = feature_corr.columns[bicluster_model.row_labels_==2]

print(gruop_2)

sns.pairplot(reduced_data, vars=gruop_2, hue=label_name)
# Out:
# Index(['SPEI_3month', 'precipitation_per_hour_v1', 'precipitation_per_hour_v2',
#        'rainfall', 'water_balance', 'wind_speed'],
#       dtype='object')
